# %%
import numpy as np
import matplotlib.pyplot as plt
import skfuzzy as fuzz
x = np.arange(0, 255, 1)
a = 125
b = 50
y = fuzz.gaussmf(x, a, b)
plt.plot(y)
plt.xlabel('x')
plt.ylabel('Derajad Keanggotaan Fuzzy')
plt.title('Fungsi Keanggotaan Gaussian')
plt.grid(True)
